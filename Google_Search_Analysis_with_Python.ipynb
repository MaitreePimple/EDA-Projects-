# %% [markdown]
# <a href="https://colab.research.google.com/github/MaitreePimple/EDA-Projects-/blob/main/Google_Search_Analysis_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pytrends

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
import time
Trending_topics = TrendReq(hl='en-US', tz=360)

# %%
kw_list=["Cloud Computing"]
Trending_topics.build_payload(kw_list,cat=0,timeframe='today 12-m')
time.sleep(5)

# %%
data = Trending_topics.interest_over_time()
data = data.sort_values(by="Cloud Computing", ascending = False)
data = data.head(10)
print(data)
# Out:
#             Cloud Computing  isPartial
# date
# 2026-02-15              100      False
# 2026-02-08               86      False
# 2025-11-16               59      False
# 2026-02-22               59      False
# 2025-11-23               57      False
# 2025-12-07               56      False
# 2025-11-30               56      False
# 2025-09-21               55      False
# 2026-02-01               52      False
# 2025-09-28               50      False
# /usr/local/lib/python3.12/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %%
kw_list = ["Cloud Computing"]
Trending_topics.build_payload(kw_list, cat=0, timeframe='2026-01-01 2026-02-01', geo='', gprop='')
data = Trending_topics.interest_over_time()
time.sleep(5)
data = data.sort_values(by="Cloud Computing", ascending = False)
data = data.head(10)
print(data)
# Out:
#             Cloud Computing  isPartial
# date
# 2026-01-22              100      False
# 2026-01-29               98      False
# 2026-01-21               95      False
# 2026-01-30               95      False
# 2026-02-01               95      False
# 2026-01-15               89      False
# 2026-01-26               89      False
# 2026-01-27               89      False
# 2026-01-28               88      False
# 2026-01-20               84      False

# %%
data = Trending_topics.interest_by_region()
data= data.sort_values(by="Cloud Computing",ascending = False)
data = data.head(10)
print(data)
# Out:
#                Cloud Computing
# geoName
# St. Helena                 100
# Nepal                       75
# South Korea                 48
# Singapore                   43
# Ethiopia                    43
# India                       41
# United States               33
# Pakistan                    31
# Canada                      30
# Nigeria                     29

# %%
data.reset_index().plot(x='geoName',y='Cloud Computing', figsize=(10,5),kind="bar")
plt.style.use('fivethirtyeight')

# %%
try:
  Trending_topics.build_payload(kw_list=['Cloud Computing'])
  time.sleep(5) # Added delay to avoid rate limiting
  related_queries = Trending_topics.related_queries()
  related_queries.values()
except(KeyError,IndexError):
  print("No related queries found for Cloud Computing")
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# /tmp/ipykernel_2135/430165491.py in <cell line: 0>()
#       2   Trending_topics.build_payload(kw_list=['Cloud Computing'])
#       3   time.sleep(5) # Added delay to avoid rate limiting
# ----> 4   related_queries = Trending_topics.related_queries()
#       5   related_queries.values()
#       6 except(KeyError,IndexError):
#
# /usr/local/lib/python3.12/dist-packages/pytrends/request.py in related_queries(self)
#     438
#     439             # parse the returned json
# --> 440             req_json = self._get_data(
#     441                 url=TrendReq.RELATED_QUERIES_URL,
#     442                 method=TrendReq.GET_METHOD,
#
# /usr/local/lib/python3.12/dist-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     157         else:
# ...

# %%
keywords = Trending_topics.suggestions(
    keyword='Cloud Computing')
df = pd.DataFrame(keywords)
df.drop(columns='mid')
# Out:
#                           title               type
# 0               Cloud computing  Organization type
# 1     Cloud Computing Explained              Topic
# 2  Cloud computing architecture              Topic
# 3      Cloud computing security              Topic
# 4          Serverless computing              Topic
